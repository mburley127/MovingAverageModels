# %% [markdown]
# #### Monte Carlo Analysis

# %%
from IPython.display import Image
Image(filename = '/Users/mburley/Downloads/GBM_MC.png', width = 500, height = 200)

# %%
### Function Calls and Outputs

from MC_Functions import import_stock_data, log_returns, drift_calc, daily_returns, simulate_mc, monte_carlo

start = "2010-1-1"
days_to_forecast = 252
simulation_trials = 10000
tickers = ['GOOG', 'AAPL', 'AMZN']

#data = import_stock_data('GOOG', start)
#print(data)

#log_rets = log_returns(data)
#print(log_rets)

#drift = drift_calc(data)
#print(drift)

#daily_rets = daily_returns(data, days_to_forecast, simulation_trials)
#print(daily_rets)

#sim = simulate_mc(data, 252, 1000, 'log')
#print(sim)

ret_sim_df = monte_carlo(tickers, days_forecast = days_to_forecast, iterations = simulation_trials,  start_date = start)
print(ret_sim_df)
# Out:
# [*********************100%%**********************]  3 of 3 completed
# [*********************100%%**********************]  1 of 1 completed
# /Users/mburley/matthew_git/StockForecasting/Monte_Carlo/MC_Functions.py:174: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, ax = ax[0])
# /Users/mburley/matthew_git/StockForecasting/Monte_Carlo/MC_Functions.py:175: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, hist_kws = {'cumulative': True}, kde_kws = {'cumulative': True}, ax = ax[1])
# GOOG
# Days: 252
# Expected Value: $214.95
# Return: 20.22%
# Probability of Breakeven: 0.7487
# Beta: 1.11
# Sharpe: 0.35
# CAPM Return: 12.37%
# /Users/mburley/matthew_git/StockForecasting/Monte_Carlo/MC_Functions.py:174: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, ax = ax[0])
# /Users/mburley/matthew_git/StockForecasting/Monte_Carlo/MC_Functions.py:175: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, hist_kws = {'cumulative': True}, kde_kws = {'cumulative': True}, ax = ax[1])
# AAPL
# Days: 252
# Expected Value: $226.78
# Return: 20.46%
# Probability of Breakeven: 0.7067
# Beta: 1.12
# Sharpe: 0.3
# CAPM Return: 12.48%
# /Users/mburley/matthew_git/StockForecasting/Monte_Carlo/MC_Functions.py:174: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, ax = ax[0])
# /Users/mburley/matthew_git/StockForecasting/Monte_Carlo/MC_Functions.py:175: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, hist_kws = {'cumulative': True}, kde_kws = {'cumulative': True}, ax = ax[1])
# AMZN
# Days: 252
# Expected Value: $180.08
# Return: 15.45%
# Probability of Breakeven: 0.6686
# Beta: 1.18
# Sharpe: 0.38
# CAPM Return: 13.04%
#     ticker           0           1           2           3           4  \
# 0     GOOG  171.479996  171.479996  171.479996  171.479996  171.479996
# 1     GOOG  169.073110  172.487746  173.717319  173.834904  165.683945
# 2     GOOG  166.797669  174.213028  178.654768  179.672833  161.983058
